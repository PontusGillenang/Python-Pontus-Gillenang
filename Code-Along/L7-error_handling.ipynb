# %% [markdown]
# # Errors
#
# - Syntax errors - Python parser don't understand the code
# - Logical errors - Error that occurs when the program runs by giving wrong results
# - Exception errors - Errors detected during execution, Python parser understands what to do, but can't do it

# %%
# Syntax error
prin("Hej hej")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\pontu\Documents\GitHub\Python-Pontus-Gillenang\Code-Along\L7-error_handling.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pontu/Documents/GitHub/Python-Pontus-Gillenang/Code-Along/L7-error_handling.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> prin("Hej hej")
#
# NameError: name 'prin' is not defined

# %%
print("Hej den här koden fungerar")
# Out:
# Hej den här koden fungerar

# %%
print("Hej"
print("då")
# Out:
#   Input In [3]
#     print("då")
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Traceback

# %%
def func1():
    print("Start function 1")
    func2()

def func2():
    print("Start function 2")
    func3()

def func3():
    print("Start function 3")
    3/0 # Exception error

func1()
# Out:
# Start function 1
# Start function 2
# Start function 3
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# c:\Users\pontu\Documents\GitHub\Python-Pontus-Gillenang\Code-Along\L7-error_handling.ipynb Cell 5 in <cell line: 13>()
#      <a href='vscode-notebook-cell:/c%3A/Users/pontu/Documents/GitHub/Python-Pontus-Gillenang/Code-Along/L7-error_handling.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a>     print("Start function 3")
#      <a href='vscode-notebook-cell:/c%3A/Users/pontu/Documents/GitHub/Python-Pontus-Gillenang/Code-Along/L7-error_handling.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a>     3/0
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pontu/Documents/GitHub/Python-Pontus-Gillenang/Code-Along/L7-error_handling.ipynb#W5sZmlsZQ%3D%3D?line=12'>13</a> func1()
#
# c:\Users\pontu\Documents\GitHub\Python-Pontus-Gillenang\Code-Along\L7-error_handling.ipynb Cell 5 in func1()
#       <a href='vscode-notebook-cell:/c%3A/Users/pontu/Documents/GitHub/Python-Pontus-Gillenang/Code-Along/L7-error_handling.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> def func1():
#       <a href='vscode-notebook-cell:/c%3A/Users/pontu/Documents/GitHub/Python-Pontus-Gillenang/Code-Along/L7-error_handling.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     print("Start function 1")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pontu/Documents/GitHub/Python-Pontus-Gillenang/Code-Along/L7-error_handling.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>     func2()
#
# c:\Users\pontu\Documents\GitHub\Python-Pontus-Gillenang\Code-Along\L7-error_handling.ipynb Cell 5 in func2()
#       <a href='vscode-notebook-cell:/c%3A/Users/pontu/Documents/GitHub/Python-Pontus-Gillenang/Code-Along/L7-error_handling.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> def func2():
#       <a href='vscode-notebook-cell:/c%3A/Users/pontu/Documents/GitHub/Python-Pontus-Gillenang/Code-Along/L7-error_handling.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a>     print("Start function 2")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pontu/Documents/GitHub/Python-Pontus-Gillenang/Code-Along/L7-error_handling.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a>     func3()
#
# c:\Users\pontu\Documents\GitHub\Python-Pontus-Gillenang\Code-Along\L7-error_handling.ipynb Cell 5 in func3()
#       <a href='vscode-notebook-cell:/c%3A/Users/pontu/Documents/GitHub/Python-Pontus-Gillenang/Code-Along/L7-error_handling.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a> def func3():
#      <a href='vscode-notebook-cell:/c%3A/Users/pontu/Documents/GitHub/Python-Pontus-Gillenang/Code-Along/L7-error_handling.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a>     print("Start function 3")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pontu/Documents/GitHub/Python-Pontus-Gillenang/Code-Along/L7-error_handling.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a>     3/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Logical error

# %%
import math

circumference = lambda radius: math.pi*radius**2

print(circumference(2))

# Program does what it has been told
# We compute the area instead of the circumference
# Logical error -> hard to find
# Out:
# 12.566370614359172
